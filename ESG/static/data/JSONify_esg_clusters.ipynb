# %%
# Import Dependencies
# from splinter import Browser
# from bs4 import BeautifulSoup
# import requests
import pandas as pd
import json
import os

# %%
group0_df = pd.read_csv('group_0.csv')
group1_df = pd.read_csv('group_1.csv')
group2_df = pd.read_csv('group_2.csv')
group3_df = pd.read_csv('group_3.csv')
group4_df = pd.read_csv('group_4.csv')
group5_df = pd.read_csv('group_5.csv')
group6_df = pd.read_csv('group_6.csv')
group7_df = pd.read_csv('group_7.csv')

# %%
group3_df.head()
# Out:
#   Ticker                   Company Name        HQ City HQ State/Province  \
# 0    ALL     Allstate Corporation (The)     Northbrook          Illinois
# 1    LNC   Lincoln National Corporation         Radnor      Pennsylvania
# 2    PFG  Principal Financial Group Inc     Des moines              Iowa
# 3     CB                  Chubb Limited        Zuerich           Zuerich
# 4    MET                   MetLife Inc.  New york city          New york
#
#                  HQ Country  ESG Risk Score ESG Risk Score Level  \
# 0  United states of america              21               Medium
# 1  United states of america              21               Medium
# 2  United states of america              22               Medium
# 3               Switzerland              23               Medium
# 4  United states of america              23               Medium
#
#   ESG Risk Score Percentile  Environment Risk Score  Social Risk Score  ...  \
# ...

# %%
group0_df = group0_df[['Ticker','Company Name','2019 Performance']]
group0_df = group0_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group1_df = group1_df[['Ticker','Company Name','2019 Performance']]
group1_df = group1_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group2_df = group2_df[['Ticker','Company Name','2019 Performance']]
group2_df = group2_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group3_df = group3_df[['Ticker','Company Name','2019 Performance']]
group3_df = group3_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group4_df = group4_df[['Ticker','Company Name','2019 Performance']]
group4_df = group4_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group5_df = group5_df[['Ticker','Company Name','2019 Performance']]
group5_df = group5_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group6_df = group6_df[['Ticker','Company Name','2019 Performance']]
group6_df = group6_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

group7_df = group7_df[['Ticker','Company Name','2019 Performance']]
group7_df = group7_df.rename(columns={"Company Name": "Company", "2019 Performance": "2019_RoR"})

# %%
group0_top20_df = group0_df.head(20)
group1_top20_df = group0_df.head(20)
group2_top20_df = group0_df.head(20)
group3_top20_df = group0_df.head(20)
group4_top20_df = group0_df.head(20)
group5_top20_df = group0_df.head(20)
group6_top20_df = group0_df.head(20)
group7_top20_df = group0_df.head(20)

# %%
# group0_top20_df.set_index('Ticker',inplace=True)
# group0_top20_df

# %%
json0 = group0_top20_df.to_json('group0.json',orient='index')
json1 = group1_top20_df.to_json('group1.json',orient='index')
json2 = group2_top20_df.to_json('group2.json',orient='index')
json3 = group3_top20_df.to_json('group3.json',orient='index')
json4 = group4_top20_df.to_json('group4.json',orient='index')
json5 = group5_top20_df.to_json('group5.json',orient='index')
json6 = group6_top20_df.to_json('group6.json',orient='index')
json7 = group7_top20_df.to_json('group7.json',orient='index')

# %%
json_print6 = group6_top20_df.to_json(orient='index')

# %%
json_print6
# Out:
# '{"0":{"Ticker":"AZO","Company":"AutoZone Inc.","2019_RoR":42.10344252},"1":{"Ticker":"RAND.AS","Company":"Randstad N.V.","2019_RoR":35.79446246},"2":{"Ticker":"AAP","Company":"Advance Auto Parts Inc W\\/I","2019_RoR":1.714721199},"3":{"Ticker":"KMX","Company":"CarMax Inc","2019_RoR":39.75769169},"4":{"Ticker":"MAN","Company":"ManpowerGroup","2019_RoR":49.84567901},"5":{"Ticker":"ORLY","Company":"O\'Reilly Automotive Inc.","2019_RoR":27.27906369},"6":{"Ticker":"ADBE","Company":"Adobe Systems Incorporated","2019_RoR":45.77881895},"7":{"Ticker":"ATO.PA","Company":"Atos SE","2019_RoR":36.69302924},"8":{"Ticker":"MAT","Company":"Mattel Inc.","2019_RoR":35.63563564},"9":{"Ticker":"CRM","Company":"Salesforce.com Inc","2019_RoR":18.74133022},"10":{"Ticker":"ACN","Company":"Accenture plc Class A (Ireland)","2019_RoR":49.32983476},"11":{"Ticker":"ADP","Company":"Automatic Data Processing Inc.","2019_RoR":30.03355705},"12":{"Ticker":"CAP.PA","Company":"Capgemini SE","2019_RoR":25.46082949},"13
# ...
